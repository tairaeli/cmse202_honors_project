# %% [markdown]
# ## Note: These notebooks are where the examples and Sag A simulations were orginally created, so the code may look very messy and may not function correctly. All the fully functional code can be found in the Writup folder along with proper descriptions as to how they work.

# %%
import matplotlib as plt
import numpy as np
import pandas as pd
from system import *
# %matplotlib inline

# %%
# importing sag a data

sagAdat = pd.read_excel("SagittariusA_data.xlsx")

# puting the data in a more usable form
sagAdat["q(m)"] = sagAdat["q (AU)"]*1.496e11 # Converting from 'AU' to 'm'
sagAdat["z"] = sagAdat["q(m)"]*np.sin(sagAdat["i (°)"]*np.pi/180) # Finding 'z' position at perihelion 
                                                                  # in cartesian coords
sagAdat["x"] = sagAdat["q(m)"]*np.cos(sagAdat["i (°)"]*np.pi/180)
sagAdat["v(m/s)"] = sagAdat["v (%c)"]*0.01*3e8 # converting star speed to m/s

# %%
# Initializing a list of star objects using the information from the dataset 
# Excluding last 3 stars due to their relativistic motion

st_list = []
for i in range(len(sagAdat["q(m)"])-3):
# for i in range(1):

    st_list.append(star([sagAdat["x"][i],0,sagAdat["z"][i]],[0,sagAdat["v(m/s)"][i],0]))

# %%
M = 2e30*4e6 # mass of Sag A
tf = 365*24*3600*100 # running for 400 years (in seconds)
dt = 365*24*3600/100 # Iterating 100 times per year

test_system = system3d(st_list,M)

test_system.iterate(tf,dt)
# Out:
# Data Instantiation Finished

# %%
# Testing iteration function
# fig = plt.figure()
ax = plt.axes(projection='3d')
for i in range(len(st_list)):
    ax.plot(st_list[i].r[:,0],st_list[i].r[:,1],st_list[i].r[:,2])
# st_list[0].r[:,0]

# plt.plot(st_list[0].r[:,0],st_list[0].r[:,1])

# %%
# plotting the 3D model
tbnd = 2 * 1.496e15 # making plot boundaries

test_system.plot([-tbnd,tbnd],[-tbnd,tbnd],[-tbnd,tbnd], tf, dt) # Still can't get the bounds right...
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-163acc6cd5ec> in <module>
#       2 tbnd = 2 * 1.496e15 # making plot boundaries
#       3
# ----> 4 test_system.plot([-tbnd,tbnd],[-tbnd,tbnd],[-tbnd,tbnd], tf, dt) # Still can't get the bounds right...
#
# ~/CMSE202/repositories/honors_project/cmse202_honors_project/3D_orbit_simulation/system.py in plot(self, xlim, ylim, zlim, tf, dt)
#     198             time.sleep(0.00001)
#     199
# --> 200             plt.cla()
#     201
#     202             clear_output(wait=True)
#
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/pyplot.py in cla()
#    2540 @_copy_docstring_and_deprecators(Axes.cla)
#    2541 def cla():
# -> 2542     return gca().cla()
#    2543
#    2544
#
# /opt/anaconda3/lib/python3.8/site-packages/mpl_toolkits/mplot3d/axes3d.py in cla(self)
#    1104         # docstring inherited.
#    1105
# -> 1106         super().cla()
#    1107         self.zaxis.cla()
#    1108
#
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py in cla(self)
#    1069             self.sharey(self._sharey)
#    1070         else:
# -> 1071             self.yaxis._set_scale('linear')
#    1072             try:
#    1073                 self.set_ylim(0, 1)
#
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/axis.py in _set_scale(self, value, **kwargs)
#     754     def _set_scale(self, value, **kwargs):
#     755         self._scale = mscale.scale_factory(value, self, **kwargs)
# --> 756         self._scale.set_default_locators_and_formatters(self)
#     757
#     758         self.isDefault_majloc = True
#
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/scale.py in set_default_locators_and_formatters(self, axis)
#     106     def set_default_locators_and_formatters(self, axis):
#     107         # docstring inherited
# --> 108         axis.set_major_locator(AutoLocator())
#     109         axis.set_major_formatter(ScalarFormatter())
#     110         axis.set_minor_formatter(NullFormatter())
#
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/ticker.py in __init__(self)
#    2918             nbins = 'auto'
#    2919             steps = [1, 2, 2.5, 5, 10]
# -> 2920         MaxNLocator.__init__(self, nbins=nbins, steps=steps)
#    2921
#    2922
#
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/ticker.py in __init__(self, *args, **kwargs)
#    2155                 raise ValueError(
#    2156                     "Keywords are required for all arguments except 'nbins'")
# -> 2157         self.set_params(**{**self.default_params, **kwargs})
#    2158
#    2159     @staticmethod
#
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/ticker.py in set_params(self, **kwargs)
#    2201         if 'nbins' in kwargs:
#    2202             self._nbins = kwargs.pop('nbins')
# -> 2203             if self._nbins != 'auto':
#    2204                 self._nbins = int(self._nbins)
#    2205         if 'symmetric' in kwargs:
#
# KeyboardInterrupt:
