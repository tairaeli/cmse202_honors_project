# %%
import matplotlib as plt
import numpy as np
import pandas as pd

# %%
SagittariusA_df = pd.read_excel("SagittariusA_data.xlsx")

SagittariusA_df.head(10)
# Out:
#      id1    id2       a      Δa       e      Δe   i (°)    Δi   Ω (°)    ΔΩ  \
# 0     S1   S0-1  0.5950  0.0240  0.5560  0.0180  119.14  0.21  342.04  0.32
# 1     S2   S0-2  0.1251  0.0001  0.8843  0.0001  133.91  0.05  228.07  0.04
# 2     S8   S0-4  0.4047  0.0014  0.8031  0.0075   74.37  0.30  315.43  0.19
# 3    S12  S0-19  0.2987  0.0018  0.8883  0.0017   33.56  0.49  230.10  1.80
# 4    S13  S0-20  0.2641  0.0016  0.4250  0.0023   24.70  0.48   74.50  1.70
# 5    S14  S0-16  0.2863  0.0036  0.9761  0.0037  100.59  0.87  226.38  0.64
# 6    S62    NaN  0.0905  0.0001  0.9760  0.0020   72.76  4.58  122.61  0.57
# 7  S4714    NaN  0.1020  0.0120  0.9850  0.0110  127.70  0.28  129.28  0.63
#
#    ...    Δω   Tp (yr)    ΔTp  P (yr)   ΔP   Kmag  q (AU)    Δq  v (%c)    Δv
# 0  ...  1.40  2001.800  0.150   166.0  5.8  14.70  2160.7   6.7    0.55  0.03
# 1  ...  0.04  2018.379  0.001    16.1  0.0  13.95   118.4   0.2    2.56  0.00
# ...

# %%
from system import *

# creating the star objects

st1 = star([1.0,0.0],[0.0,2*np.pi])

st2 = star([2.0,0.0],[0.0,2*np.pi])

st3 = star([0.5,0.0],[0.0,2*np.pi])

st4 = star([3.0,0.0],[0.0,2*np.pi])

st_list = [st1,st2,st3,st4]

# %%
# %reload_ext autoreload
# %autoreload 2
# %pylab
# %matplotlib inline
from IPython.display import display, clear_output

# running the iteration function

tf = 100
dt = 0.001

test_system = system2d(st_list)

test_system.iterate(tf,dt)
# Out:
# Using matplotlib backend: agg
# Populating the interactive namespace from numpy and matplotlib
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-7645c84a2833> in <module>
#      10 dt = 0.001
#      11
# ---> 12 test_system = system2d(st_list)
#      13
#      14 test_system.iterate(tf,dt)
#
# TypeError: __init__() missing 1 required positional argument: 'M'

# %%
# showing the animation of the movement of the stars

fig, ax = plt.subplots(figsize = (10,10))

n = np.arange(0,tf*1/dt,50)

for i in n:
    
    test_system.plot(st_list,int(i),[-5,5],[-5,5])

    clear_output(wait=True) 
    display(fig)            
    fig.clear()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-ed49a40b2f08> in <module>
#      11     clear_output(wait=True)
#      12     display(fig)
# ---> 13     fig.clear()
#
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/figure.py in clear(self, keep_observers)
#    1815     def clear(self, keep_observers=False):
#    1816         """Clear the figure -- synonym for `clf`."""
# -> 1817         self.clf(keep_observers=keep_observers)
#    1818
#    1819     @allow_rasterization
#
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/figure.py in clf(self, keep_observers)
#    1793
#    1794         for ax in tuple(self.axes):  # Iterate over the copy.
# -> 1795             ax.cla()
#    1796             self.delaxes(ax)         # removes ax from self._axstack
#    1797
#
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py in cla(self)
# ...
