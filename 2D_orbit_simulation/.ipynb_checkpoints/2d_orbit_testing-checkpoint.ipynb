# %%
import matplotlib as plt
import numpy as np

# %%
# %reload_ext autoreload
# %autoreload 2
from system_v2 import *

# creating the star objects

st1 = star([(3.086e+16/0.595),0.0],[0.0,(5.5e-6*3e8)])

st2 = star([2,0.0],[0.0,2*np.pi])

st3 = star([0.5,0.0],[0.0,2*np.pi])

st4 = star([3,0.0],[0.0,2*np.pi])

st_list = [st1]

# %%
# %reload_ext autoreload
# %autoreload 2
# %pylab
# %matplotlib inline
from IPython.display import display, clear_output

# running the iteration function

tf = 3.154e+7*1000
dt = 3.154e+7/1000

test_system = system2d(st_list,2e30*10e6)

test_system.iterate(tf,dt)
# Out:
# Using matplotlib backend: Qt5Agg
# Populating the interactive namespace from numpy and matplotlib

# %%
plt.plot(st1.r[:,0],st1.r[:,1])

# %%
# showing the animation of the movement of the stars

fig, ax = plt.subplots(figsize = (10,10))

n = np.arange(0,tf*1/dt,50)

for i in n:
    
    test_system.plot(st_list,int(i),[-10,10],[-10,10])

    clear_output(wait=True) 
    display(fig)            
    fig.clear()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20768/3274273885.py in <module>
#      11     clear_output(wait=True)
#      12     display(fig)
# ---> 13     fig.clear()
#
# ~\anaconda3\lib\site-packages\matplotlib\figure.py in clear(self, keep_observers)
#    2752     def clear(self, keep_observers=False):
#    2753         """Clear the figure -- synonym for `clf`."""
# -> 2754         self.clf(keep_observers=keep_observers)
#    2755
#    2756     @_finalize_rasterization
#
# ~\anaconda3\lib\site-packages\matplotlib\figure.py in clf(self, keep_observers)
#    2727
#    2728         for ax in tuple(self.axes):  # Iterate over the copy.
# -> 2729             ax.cla()
#    2730             self.delaxes(ax)         # removes ax from self._axstack
#    2731
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in cla(self)
#    1295
# ...

# %%
plt.plot(st1.r[:,0],st1.r[:,1])
